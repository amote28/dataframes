# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.ticker as ticker

# %%
df = pd.read_csv(r'C:\Users\sereb\Downloads\chains (1).csv', index_col= "Date", parse_dates= True)
df = df[df.index >= '2021-09-14']
df.fillna(0, inplace=True)

# %%
df['Rollups']= df['Optimism'] + df['Arbitrum']
df['SoLunAvax'] = df['Solana'] + df['Avalanche'] + df['Terra Classic'] + df['Terra2']
df = df[['Rollups', 'SoLunAvax']]
df
# Out:
#                  Rollups     SoLunAvax
# Date
# 2021-09-14  1.834422e+09  1.463588e+10
# 2021-09-15  1.308091e+09  1.480991e+10
# 2021-09-16  6.145203e+08  1.464900e+10
# 2021-09-17  5.348643e+08  1.436753e+10
# 2021-09-18  7.586357e+08  1.519095e+10
# ...                  ...           ...
# 2023-01-27  1.864424e+09  1.206399e+09
# 2023-01-28  1.896749e+09  1.270178e+09
# 2023-01-29  1.915146e+09  1.257982e+09
# 2023-01-30  1.948209e+09  1.271765e+09
# 2023-01-31  1.948698e+09  1.248555e+09
#
# [505 rows x 2 columns]

# %%
df.plot(title='Rollups and SoLunAvax TVL', figsize=(16,6))
ax = plt.gca()
formatter = ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1e9) + 'bln')
ax.yaxis.set_major_formatter(formatter)
plt.show()

# %%
df['Ratio']=df['SoLunAvax']/df['Rollups']
df['Ratio'].plot(title='Ratio of SoLunAvax to Arbitrum+Optimism TVL', figsize=(16,6))
# Out:
# <AxesSubplot: title={'center': 'Ratio of SoLunAvax to Arbitrum+Optimism TVL'}, xlabel='Date'>
